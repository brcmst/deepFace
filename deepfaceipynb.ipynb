# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 53.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 12.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116934 sha256=4b0c0aad6229c4b37dbbe650aa7620c22440954f70a2aa238b6141d6d0cccac6
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
im_path = "/content/images.jpg"
im = cv2.imread(im_path)
plt.imshow(im[:,:,::-1])
plt.show()
resp = DeepFace.analyze(im_path)
print(resp)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.83it/s]
# [{'emotion': {'angry': 0.0991114997304976, 'disgust': 0.05030640750192106, 'fear': 1.2906239368021488, 'happy': 39.24814164638519, 'sad': 2.4697132408618927, 'surprise': 0.051016866927966475, 'neutral': 56.79108500480652}, 'dominant_emotion': 'neutral', 'region': {'x': 64, 'y': 30, 'w': 78, 'h': 78}, 'face_confidence': 7.987467123835813, 'age': 30, 'gender': {'Woman': 99.8751163482666, 'Man': 0.1248788321390748}, 'dominant_gender': 'Woman', 'race': {'asian': 0.0167021231489519, 'indian': 0.008655301340270255, 'black': 0.00020866902800601852, 'white': 95.4672699609673, 'middle eastern': 1.6948908409606407, 'latino hispanic': 2.8122688085116376}, 'dominant_race': 'white'}]

# %%
resp
# Out:
# [{'emotion': {'angry': 0.0991114997304976,
#    'disgust': 0.05030640750192106,
#    'fear': 1.2906239368021488,
#    'happy': 39.24814164638519,
#    'sad': 2.4697132408618927,
#    'surprise': 0.051016866927966475,
#    'neutral': 56.79108500480652},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 64, 'y': 30, 'w': 78, 'h': 78},
#   'face_confidence': 7.987467123835813,
#   'age': 30,
#   'gender': {'Woman': 99.8751163482666, 'Man': 0.1248788321390748},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 0.0167021231489519,
#    'indian': 0.008655301340270255,
#    'black': 0.00020866902800601852,
#    'white': 95.4672699609673,
#    'middle eastern': 1.6948908409606407,
#    'latino hispanic': 2.8122688085116376},
#   'dominant_race': 'white'}]
